# %%
import requests 
import json
import pandas as pd 
from bs4 import BeautifulSoup

# %%
import urllib.request as req
url = "https://www.cwa.gov.tw/V8/C/C/Statistics/monthlymean.html"
request = req.Request(url, headers= {
    "User-Agent":"Mozilla/5.0 (Windows NT 10.0; Win64; x64) AppleWebKit/537.36 (KHTML, like Gecko) Chrome/119.0.0.0 Safari/537.36"
})
with req.urlopen(request) as response:
    data = response.read().decode("utf-8")
print(data)
# Out:
# <!DOCTYPE html>
# <!--[if IE 8]> <html lang="zh-Hant-TW" class="ie8"> <![endif]-->
# <!--[if IE 9]> <html lang="zh-Hant-TW" class="ie9"> <![endif]-->
# <!--[if !IE]><!-->
# <html lang="zh-Hant-TW">
# <!--<![endif]-->
#
# <head>
#   <title>氣候月平均 | 交通部中央氣象署</title>
#   <!-- Meta -->
#   <meta charset="utf-8">
#   <meta name="viewport" content="width=device-width, initial-scale=1.0">
#   <meta name="description" content="">
#   <meta name="author" content="">
#   <!--Facebook_meta_begin-->
#   <!-- Facebook -->
#   <meta property="og:url" content="https://www.cwa.gov.tw/V8/C/C/Statistics/monthlymean.html" />
#   <meta property="og:image" content="https://www.cwa.gov.tw/Data/satellite/TWI_IR1_CR_800/TWI_IR1_CR_800.jpg" />
#   <meta property="og:title" content="氣候月平均資料 - 中央氣象署全球資訊網" />
#   <meta property="og:description" content="天氣,風向,風力,陣風,濕度,氣壓,雨量,日照,雲量月平均資料月平均資料。" />
#   <meta property="og:site_name" content="中央氣象署全球資訊網" />
#   <!--Facebook_meta_end-->
#   <!--tw.gov_meta_begin-->
#   <meta name="DC.Creator" content="交通部中央氣象署" />
#   <meta name="DC.Contributor" content="交通部中央氣象署" />
#   <meta name="DC.Type" content="服務" />
#   <meta name="DC.Format" content="text" />
#   <meta name="DC.Source" content="交通部中央氣象署" />
#   <meta name="DC.Language" content="中文" />
#   <meta name="DC.coverage.t.min" content="2023-09-21" />
#   <meta name="DC.coverage.t.max" content="2028-09-21" />
#   <meta name="DC.Publisher" content="交通部中央氣象署" />
#   <meta name="DC.Date" content="2023-09-21 15:56" />
#   <meta name="DC.Identifier" content="A15020000H" />
#   <meta name="DC.Relation" content="" />
#   <meta name="DC.Rights" content="交通部中央氣象署" />
#   <meta name="Category.Theme" content="650" />
#   <meta name="Category.Cake" content="CM0" />
#   <meta name="Category.Service" content="EZ0" />
#   <meta name="DC.Title" content="中央氣象署全球資訊網" />
#   <meta name="DC.Subject" content="氣候" />
#   <meta name="DC.Description" content="氣候統計" />
#   <meta name="Keywords" content="天氣,風向,風力,陣風,濕度,氣壓,雨量,日照,雲量" />
#   <!--tw.gov_meta_end-->
#   <!-- Favicon -->
#   <link rel="shortcut icon" href="/V8/favicon.ico">
#   <!-- =============== CSS Global Compulsory =============== -->
#   <!--common_css_begin-->
#   <meta http-equiv="X-UA-Compatible" content="IE=edge">
#   <meta name="application-name" content="中央氣象署">
#   <meta name="msapplication-TileImage" content="/V8/assets/img/win10/cwbPinlogo.png">
#   <meta name="msapplication-square70x70logo" content="/V8/assets/img/win10/cwbPinlogo70.png">
#   <meta name="msapplication-square150x150logo" content="/V8/assets/img/win10/cwbPinlogo150.png">
#   <meta name="msapplication-square310x310logo" content="/V8/assets/img/win10/cwbPinlogo310.png">
#   <link rel="shortcut icon" href="/favicon.ico">
#   <link rel="stylesheet" href="/V8/assets/plugins/bootstrap/css/bootstrap.min.css?v=20230418">
#   <link rel="stylesheet" href="/V8/assets/plugins/font-awesome/css/font-awesome.min.css?v=20191223">
#   <link rel="stylesheet" href="/V8/assets/plugins/cwb-fonticon/style.css?v=20230601">
#   <link rel="stylesheet" href="/V8/assets/plugins/plugins.css?v=20191223">
#   <link rel="stylesheet" href="/V8/assets/css/main.css?v=20230914">
#   <!-- Google Tag Manager -->
#   <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-P7QGZ2G');</script>
#   <script>(function(w,d,s,l,i){w[l]=w[l]||[];w[l].push({'gtm.start':
#   new Date().getTime(),event:'gtm.js'});var f=d.getElementsByTagName(s)[0],
#   j=d.createElement(s),dl=l!='dataLayer'?'&l='+l:'';j.async=true;j.src=
#   'https://www.googletagmanager.com/gtm.js?id='+i+dl;f.parentNode.insertBefore(j,f);
#   })(window,document,'script','dataLayer','GTM-MXGLP2G');</script>
#   <!-- End Google Tag Manager -->
#   <!--common_css_end-->
# </head>
#
# <body>
#   <a class="focusable" href="#center-content" title="跳到主要內容區塊" tabindex="1">跳到主要內容區塊</a>
#   <noscript>
#     <!-- Google Tag Manager (noscript) -->
#     <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-P7QGZ2G" title="GTM" height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     <iframe src="https://www.googletagmanager.com/ns.html?id=GTM-MXGLP2G" title="GTM" height="0" width="0" style="display:none;visibility:hidden"></iframe>
#     <!-- End Google Tag Manager (noscript) -->
#     <h2>您的瀏覽器不支援JavaScript功能，若網頁功能無法正常使用時，請開啟瀏覽器JavaScript狀態。</h2>
#     <a href="/V8/C/sitemap.html" target="_self" title="可點此前往" style="font-size:1.2rem;">網站導覽</a>
#   </noscript>
#   <!--=== Header ===-->
#   <header class="header" id="header"></header>
#   <!--=== End Header ===-->
#   <!--=== Breadcrumbs ===-->
#   <div class="breadcrumbs">
#     <div class="container">
# 	  <a href="#center-content" accesskey="C" id="center-content" class="acc" title=":::中間內容區導盲磚">:::</a>
#       <ul class="pull-right breadcrumb breadcrumb-left">
#         <li><a href="/V8/C/index.html" aria-label="首頁" target="_self"><i class="fa fa-home" aria-hidden="true" title="首頁"></i><span class="sr-only">首頁</span></a></li>
#         <li>氣候</li>
#         <li>氣候統計</li>
#         <li>氣候月平均</li>
#       </ul>
#     </div>
#   </div>
#   <!--=== End Breadcrumbs ===-->
#   <div class="main-title-bar">
#     <div class="container">
#       <h2 class="main-title">
#         <i class="icon-cwb-cloud" aria-hidden="true"></i>氣候月平均</h2>
#     </div>
#   </div>
#   <!--=== Content Part ===-->
#   <form action="#" class="sky-form">
#     <fieldset>
# 	  <legend><span class="sr-only">選擇縣市</span></legend>
#       <div class="container">
#         <div class="row">
#           <div class="col-sm-3 col-sm-offset-1">
#             <label class="label text-right">請選擇</label>
#           </div>
#           <div class="col-md-2 col-sm-3">
#             <label class="select">
#               <select id="Location">
#                 <option value="Taiwan" selected>臺灣</option>
#                 <option value="China">中國</option>
#                 <option value="World">全球</option>
#               </select>
#               <i aria-hidden="true"></i>
#           </div>
#           <div class="col-sm-2">
#             <label class="select">
#               <select id="Item">
#                     <option value="sunshine">日照時數</option>
# 					<option value="meantxmin">最低氣溫</option>
# 					<option value="txminle10day">最低氣溫&lt;=10℃日數</option>
# 					<option value="meantxmax">最高氣溫</option>
# 					<option value="txmaxge30day">最高氣溫>=30℃日數</option>
# 					<option value="tx" selected>氣溫</option>
# 					<option value="txge25day">氣溫>=25℃日數</option>
# 					<option value="stnpres">測站氣壓</option>
# 					<option value="rh">相對濕度</option>
# 					<option value="precp">降水量（平均）</option>
# 					<option value="precp-median">降水量（中位數）</option>
# 					<option value="precpday">降水量>=0.1mm日數</option>
# 					<option value="CamtMean">雲量</option>
# 					<option value="ws">風速</option>
#               </select>
#               <i aria-hidden="true"></i>
#             </div>
#           </div>
#         </div>
#       </div>
#     </fieldset>
#   </form>
#   <div class="wrapper">
#     <main class="main-content">
#       <div class="container">
#         <div class="row">
#           <div class="col-md-12">
#             <h3 id="SubTitle" class="sm_subtitle">降水量<span class="notes">單位：毫米</span>
#             </h3>
#               <div class="flex_table mobile_table-month">
#                 <div class="btn-group">
#                  <a role="button" aria-label="上一頁" id="back"><i class="fa  fa-long-arrow-left"></i></a>
#                  <a role="button" aria-label="下一頁" id="next"><i class="fa  fa-long-arrow-right"></i></a>
#                 </div>
#                 <table class="table table-striped">
#                 <thead>
#                   <tr>
#                     <th id="loc" scope="col"></th>
#                     <th id="m0" scope="col" class="is_show">一月</th>
#                     <th id="m1" scope="col" class="is_show">二月</th>
#                     <th id="m2" scope="col" class="is_show">三月</th>
#                     <th id="m3" scope="col" class="is_show">四月</th>
#                     <th id="m4" scope="col">五月</th>
#                     <th id="m5" scope="col">六月</th>
#                     <th id="m6" scope="col">七月</th>
#                     <th id="m7" scope="col">八月</th>
#                     <th id="m8" scope="col">九月</th>
#                     <th id="m9" scope="col">十月</th>
#                     <th id="m10" scope="col">十一月</th>
#                     <th id="m11" scope="col">十二月</th>
#                     <th id="item" scope="col">平均</th>
#                     <th id="period" scope="col" style="width: 1500px;">統計期間</th>
#                   </tr>
#                 </thead>
#                 <tbody id="MonthlyMean_MOD"></tbody>
#                 </table>
#               </div>
#           </div>
#           <div class="col-md-12">
#             <div class="other">
#               <h4 class="note">註</h4>
#               <ul class="list-unstyled">
#                 <li>月平均資料為30年平均值。每10年更新一次，更新時間為次年1月底前，例如：1991-2020年月平均資料，更新日期為2021年1月底年完成更新。
#                 </li>
#               </ul>
#             </div>
#           </div>
#         </div>
#       </div>
#     </main>
#   </div>
#   <!--/wrapper-->
#   <!--/container-->
#   <!-- End Content Part -->
#   <!--=== Footer ===-->
#   <footer id="footer-v3" class="footer-v3">
#
#   </footer>
#   <!--=== End Footer ===-->
#   <!--common_js_begin-->
#   <script src="/Data/js/warn/Warning_Content.js?"></script>
#   <script src="/Data/js/info/Info_Warning.js?v=20230116"></script>
#   <script src="/Data/js/info/Info_County.js?v=20200415"></script>
#   <script src="/Data/js/info/Info_Town.js?v=20200817"></script>
#   <script src="/V8/assets/plugins/jquery/jquery-2.2.4.min.js"></script>
#   <script src="/V8/assets/plugins/jquery/jquery-migrate.min.js"></script>
#   <script src="/V8/assets/plugins/jquery-ui/jquery-ui.min.js"></script>
#   <script src="/V8/assets/plugins/bootstrap/js/bootstrap.min.js"></script>
#   <script src="/V8/assets/plugins/back-to-top.js?v=20230526"></script>
#   <script src="/V8/assets/plugins/smoothScroll.js"></script>
#   <script src="/V8/assets/js/cookie_lib.js?v=20201217"></script>
#   <script src="/V8/assets/js/function-global.js?v=20230921"></script>
#   <script src="/V8/assets/js/app.js"></script>
#   <!--common_js_end-->
#   <!-- JS Customization -->
#   <script type="text/javascript" src="/V8/assets/js/function-table.js"></script>
#   <script type="text/javascript">
#     // 手機版表格切換欄位數
# 	var VER = "C";
#     var interval = [4, 4, 4, 2];
#
#     jQuery(document).ready(function() {
#       App.init();
# 	  console.log("load start");
# 	  DefaultLocation = $("#Location").val();
# 	  DefaultItem = $("#Item").val();
# 	  GetMOD(VER, DefaultLocation, DefaultItem, '#MonthlyMean_MOD');
#     });
#
#    function HtmlEscape(input) {
# 	  return decodeURI(encodeURI(input));
#    }
#
#    function GetMOD(VER, Location, Item, TARGET_DIV) {
#
# 	 var date = new Date();
#      var TimeString = date.getMilliseconds();
# 	 var MOD_DIR = "/V8/"+VER+"/C/Statistics/MonthlyMean/MOD/";
# 	 var MOD_FILE = Location+"_"+Item+".html?ID="+TimeString;
# 	 //alert(MOD_DIR+MOD_FILE);
#
# 	 $.get(MOD_DIR+MOD_FILE, '', function(data) {
# 		$(TARGET_DIV).html(HtmlEscape(data));
# 		var ItemText = $("#Item option:selected").text();
# 		var TableTitle = $('#MonthlyMean_MOD tr:first-child').data('tabletitle');
# 		var TableUnit = $('#MonthlyMean_MOD tr:first-child').data('tableunit');
# 		if (TableTitle=="降水量")  TableTitle="降水量（平均）";
# 		$('#SubTitle').html(TableTitle+"<span class=\"notes\">單位："+TableUnit+"</span>");
#         //alert(data);
# 		console.log( 'Get '+MOD_FILE+' Success' );
# 	 }).fail(function(){
# 		console.log( 'Get '+MOD_FILE+' Failed!' );
# 	 });
#
# 	    jQuery.ajaxSetup({
# 		async: true
# 	    });
#
#      }
#
#      $("#Location").change(function() {
# 			SelectLocation = $("#Location").val();
#
#             //中國和全球只有4個選項
# 			if (SelectLocation != "Taiwan") {
#               $("#Item option[value='sunshine']").hide();
# 			  $("#Item option[value='meantxmin']").show();
# 			  $("#Item option[value='txminle10day']").hide();
# 			  $("#Item option[value='meantxmax']").show();
# 			  $("#Item option[value='txmaxge30day']").hide();
# 			  $("#Item option[value='tx']").hide();
# 			  $("#Item option[value='txge25day']").hide();
# 			  $("#Item option[value='stnpres']").hide();
# 			  $("#Item option[value='rh']").hide();
# 			  $("#Item option[value='precp']").show();
# 			  $("#Item option[value='precp-median']").hide();
# 			  $("#Item option[value='precpday']").show();
# 			  $("#Item option[value='CamtMean']").hide();
# 			  $("#Item option[value='ws']").hide();
# 			  SelectItem = "meantxmin";
# 			  $("#Item option[value='meantxmin']").attr('selected','selected');
#         	} else {
# 			  $("#Item option[value='sunshine']").show();
# 			  $("#Item option[value='meantxmin']").show();
# 			  $("#Item option[value='txminle10day']").show();
# 			  $("#Item option[value='meantxmax']").show();
# 			  $("#Item option[value='txmaxge30day']").show();
# 			  $("#Item option[value='tx']").show();
# 			  $("#Item option[value='txge25day']").show();
# 			  $("#Item option[value='stnpres']").show();
# 			  $("#Item option[value='rh']").show();
# 			  $("#Item option[value='precp']").show();
# 			  $("#Item option[value='precp-median']").show();
# 			  $("#Item option[value='precpday']").show();
# 			  $("#Item option[value='CamtMean']").show();
# 			  $("#Item option[value='ws']").show();
#               SelectItem = $("#Item").val();
#             }
#             change(0);count = 0;
# 			GetMOD(VER, SelectLocation, SelectItem, '#MonthlyMean_MOD');
# 	 });
#
# 	 $("#Item").change(function() {
# 			SelectLocation = $("#Location").val();
# 			SelectItem = $("#Item").val();
# 			  change(0);count = 0;
# 			  GetMOD(VER, SelectLocation, SelectItem, '#MonthlyMean_MOD');
# 			  total = ["sunshine", "txminle10day", "txmaxge30day", "txge25day", "precp", "precpday"];
# 			  if (total.indexOf(SelectItem)!= "-1")
# 			    $('#item').html('合計');
# 			  else
#                 $('#item').html('平均');
#
# 	 });
#
#   </script>
#   <!--[if lt IE 9]>
#     <script src="/V8/assets/plugins/IE/respond.js"></script>
#     <script src="/V8/assets/plugins/IE/html5shiv.js"></script>
#     <script src="/V8/assets/plugins/IE/placeholder-IE-fixes.js"></script>
#     <![endif]-->
# </body>
#
# </html>

# %%
# 示例：提取表格数据
table = soup.find('table')

# 检查是否找到表格
if table:
    rows = table.find_all('tr')

    # 创建一个空的列表，用于存储提取的数据
    data_list = []

    # 遍历表格的每一行，提取数据并添加到列表中
    for row in rows:
        cells = row.find_all(['td', 'th'])
        row_data = [cell.text.strip() for cell in cells]
        data_list.append(row_data)

    # 将数据列表转换为 JSON 格式
    json_data = json.dumps(data_list, ensure_ascii=False)

    # 将 JSON 数据写入文件
    with open('氣候月平均.json', 'w', encoding='utf-8') as json_file:
        json_file.write(json_data)

    print("JSON file has been created successfully.")
# Out:
# JSON file has been created successfully.

# %%
test = open('氣候月平均.json', encoding= "utf8")
data = json.load(test)
type(data)
# Out:
# list

# %%
data.items()
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_12128\2157004318.py in <module>
# ----> 1 data.items()
#
# AttributeError: 'list' object has no attribute 'items'
